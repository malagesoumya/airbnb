# %% [markdown]
# <a href="https://colab.research.google.com/github/malagesoumya/airbnb/blob/main/airbnb_project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('/content/Airbnb NYC 2019 - Airbnb NYC 2019 2.csv')
df1
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df1.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df1.tail()
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 48890        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 48891        Marisol            Brooklyn            Bushwick  40.70184
# 48892  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 48893            Taz           Manhattan      Hell's Kitchen  40.75751
# 48894     Christophe           Manhattan      Hell's Kitchen  40.76404
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df1[df1['host_name'].isna()]
# Out:
#              id                                               name    host_id  \
# 360      100184                                          Bienvenue     526653
# 2700    1449546                            Cozy Studio in Flatbush    7779204
# 5745    4183989    SPRING in the City!! Zen-Style Tranquil Bedroom     919218
# 6075    4446862                 Charming Room in Prospect Heights!   23077718
# 6582    4763327                Luxurious, best location, spa inc'l   24576978
# 8163    6292866                          Modern Quiet Gem Near All   32722063
# 8257    6360224                    Sunny, Private room in Bushwick   33134899
# 8852    6786181                       R&S Modern Spacious Hideaway   32722063
# 9138    6992973                    1 Bedroom in Prime Williamsburg    5162530
# 9817    7556587                               Sunny Room in Harlem   39608626
# 14040  10709846                 Sunny, spacious room in Greenpoint    7822683
# ...

# %%
df1.isna().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# 1. Distribution of Airbnb Price Range

# %%
df1['price'].describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.histplot(df1['price'],bins=200)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# 2. Find total listings/property count for each neighbourhood_group in nyc

# %%
neigh_grp=df1['neighbourhood_group'].value_counts().reset_index()
neigh_grp
# Out:
#   neighbourhood_group  count
# 0           Manhattan  21661
# 1            Brooklyn  20104
# 2              Queens   5666
# 3               Bronx   1091
# 4       Staten Island    373

# %%
neighbourhood_grp=df1['neighbourhood_group'].value_counts().reset_index()

# %%
sns.barplot(x='neighbourhood_group',y='count',data=neighbourhood_grp)
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='count'>

# %% [markdown]
# 3.Average price in neighbourhood groups and each neighbourhood

# %%
n_avg = df1.groupby('neighbourhood')['price'].mean().reset_index(name = 'Avg_price')
n_avg
# Out:
#        neighbourhood   Avg_price
# 0           Allerton   87.595238
# 1      Arden Heights   67.250000
# 2           Arrochar  115.000000
# 3            Arverne  171.779221
# 4            Astoria  117.187778
# ..               ...         ...
# 216  Windsor Terrace  138.993631
# 217        Woodhaven   67.170455
# 218         Woodlawn   60.090909
# 219          Woodrow  700.000000
# 220         Woodside   85.097872
#
# [221 rows x 2 columns]

# %% [markdown]
# 4.find top neighbourhoods and hosts by listing in entire nyc

# %%
 n_top=df1['neighbourhood'].value_counts().reset_index(name='no of listings').head(10)
 n_top
# Out:
#         neighbourhood  no of listings
# 0        Williamsburg            3920
# 1  Bedford-Stuyvesant            3714
# 2              Harlem            2658
# 3            Bushwick            2465
# 4     Upper West Side            1971
# 5      Hell's Kitchen            1958
# 6        East Village            1853
# 7     Upper East Side            1798
# 8       Crown Heights            1564
# 9             Midtown            1545

# %%
sns.barplot(x='neighbourhood',y='no of listings',data=n_top)
plt.figure(figsize=(20,5))
plt.title('top 10 neighbourhood by listings')
# Out:
# Text(0.5, 1.0, 'top 10 neighbourhood by listings')

# %% [markdown]
# 5.find the number of active hosts per location by eac neighbourhood group

# %%
df1.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
active_hosts_by_n_grp = df1.groupby('neighbourhood_group')['host_id'.nunique().reset_index('name')]
active_hosts_by_n_grp
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-25409cf1faa4> in <cell line: 1>()
# ----> 1 active_hosts_by_n_grp = df1.groupby('neighbourhood_group')['host_id'.nunique().reset_index('name')]
#       2 active_hosts_by_n_grp
#
# AttributeError: 'str' object has no attribute 'nunique'

# %% [markdown]
# 6.find total count of room type in nyc

# %%
df1['room_type'].value_counts().reset_index().plot(kind='bar',x='room_type',y='count')
# Out:
# <Axes: xlabel='room_type'>

# %% [markdown]
# 7.find stay requirements by minimum nights

# %%
sns.histplot(df1['minimum_nights'],kde=True)
# Out:
# <Axes: xlabel='minimum_nights', ylabel='Count'>

# %%
df1['minimum_nights'].describe()
# Out:
# count    48895.000000
# mean         7.029962
# std         20.510550
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64

# %%
sns.boxplot(df1['minimum_nights'])
# Out:
# <Axes: ylabel='minimum_nights'>

# %%
from scipy.stats import skew
df1['minimum_nights'].skew()
# Out:
# 21.827274529642168

# %%
sns.boxplot(df1['minimum_nights'])
# Out:
# <Axes: ylabel='minimum_nights'>

# %% [markdown]
# 8.total no of reviews and maximum reviews by each neighbourhood grp

# %%
n_review=df1.groupby('neighbourhood_group')['number_of_reviews'].sum().max()
n_review
# Out:
# 486574

# %%
n_review_max=df1.groupby('neighbourhood_group')['number_of_reviews'].max()
n_review
# Out:
# 486574

# %% [markdown]
# 9.find most reviewed room type in neighbourhood groups per month

# %%
r_type = df1.groupby(['neighbourhood_group','room_type'])['reviews_per_month'].mean().unstack()
r_type
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                       2.238123      1.641660     1.351860
# Brooklyn                    1.317630      1.255758     1.070966
# Manhattan                   1.141610      1.448949     1.792781
# Queens                      1.967302      1.947959     1.522895
# Staten Island               2.074400      1.699182     1.332000

# %%
plt.figure(figsize = (12,8))
sns.heatmap(r_type,annot=True)
# Out:
# <Axes: xlabel='room_type', ylabel='neighbourhood_group'>

# %%
sns.barplot(r_type[['neighbourhood_group','room_type']],['reviews_per_month',hue = 'room_type',data = r_type)
# Out:
#   File "<ipython-input-12-a584f95e234e>", line 1
#     sns.barplot(r_type[['neighbourhood_group','room_type']],['reviews_per_month',hue = 'room_type',data = r_type)
#                                                                                                                 ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %% [markdown]
# 10.find best location listing/property location for hosts

# %%
df1.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df1.host_name.value_counts()
# Out:
# host_name
# Michael              417
# David                403
# Sonder (NYC)         327
# John                 294
# Alex                 279
#                     ...
# Rhonycs                1
# Brandy-Courtney        1
# Shanthony              1
# Aurore And Jamila      1
# Ilgar & Aysel          1
# Name: count, Length: 11452, dtype: int64

# %%
df1[df1['host_name']=='Michael']
# Out:
#              id                                            name    host_id  \
# 151       36121              Lg Rm in Historic Prospect Heights      62165
# 412      138216              Sunny and Spacious Designer's Home     674970
# 519      189135             Hell's Kitchen Funky 80's Hideaway!     179020
# 616      233189             NYC Studio in Heart of Times Square    1220414
# 811      289037                2BR in Cobble Hill, Brooklyn, NY     632334
# ...         ...                                             ...        ...
# 48378  36228909           Sunny SoHo Penthouse w/ Pvt. Terrace!  272485928
# 48531  36310247          Spacious 1 Bedroom With Private Garden   25498509
# 48786  36426788  Serene Room 5 mins from JFK / 15 mins from LGA  266645207
# 48830  36450318    LUXURY, PRIVATE APT ACROSS FROM EMPIRE STATE  151831356
# 48889  36484363                              QUIT PRIVATE HOUSE  107716952
#
# ...

# %%
df1.groupby('name')['number_of_reviews'].max().sort_values(ascending=False)
# Out:
# name
# Room near JFK Queen Bed                                         629
# Great Bedroom in Manhattan                                      607
# Beautiful Bedroom in Manhattan                                  597
# Private Bedroom in Manhattan                                    594
# Room Near JFK Twin Beds                                         576
#                                                                ...
# Ample Central Midtown East 1BR w/ Gym, Doorman by Blueground      0
# New York City UES Luxury Doorman Building                         0
# Ample 1BR w/ Indoor pool, Gym near Broadway by Blueground         0
# New York City escape                                              0
# ﾏﾝﾊｯﾀﾝ､駅から徒歩4分でどこに行くのにも便利な場所!女性の方希望,ｷﾚｲなお部屋｡                      0
# Name: number_of_reviews, Length: 47883, dtype: int64

# %%
df1.groupby('neighbourhood'['calculated_host_listings_count'].sum().sort_values(ascending=False))
# Out:
# <>:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
# <>:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
# <ipython-input-17-7634360298ec>:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
#   df1.groupby('neighbourhood'['calculated_host_listings_count'].sum().sort_values(ascending=False))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-7634360298ec> in <cell line: 1>()
# ----> 1 df1.groupby('neighbourhood'['calculated_host_listings_count'].sum().sort_values(ascending=False))
#
# TypeError: string indices must be integers

# %% [markdown]
# 12.price variations in nyc neighbourhood group

# %%
sns.boxplot(x='neighbourhood_group',y='price',data=df1)
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %%
for i in df1['neighbourhood_group'].nunique():
  n_check=df1[df1['neighbourhood_group']==i]
  sns.histplot(x='neighbourhood_group',y='price',data=n_check)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-853d159c90c8> in <cell line: 1>()
# ----> 1 for i in df1['neighbourhood_group'].nunique():
#       2   n_check=df1[df1['neighbourhood_group']==i]
#       3   sns.histplot(x='neighbourhood_group',y='price',data=n_check)
#
# TypeError: 'int' object is not iterable

# %%
all_grp = df1['neighbourhood_group'].unique()
all_grp
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
fig, axes plt.subplots(nrows=2,ncols=3,figsize=(18,10),tight_layout=True)
# Out:
#   File "<ipython-input-23-8602ce341894>", line 1
#     fig, axes plt.subplots(nrows=2,ncols=3,figsize=(18,10),tight_layout=True)
#               ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(18,8))
for i in df1['neighbourhood_group'].nunique():
  df1[df1['neighbourhood_group']==i]
  sns.histplot(n_check['price'],bins=50,kde=True,label=i)
  plt.title(f"price distribution {i}")
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-d8384a835421> in <cell line: 2>()
#       1 plt.figure(figsize=(18,8))
# ----> 2 for i in df1['neighbourhood_group'].nunique():
#       3   df1[df1['neighbourhood_group']==i]
#       4   sns.histplot(n_check['price'],bins=50,kde=True,label=i)
#       5   plt.title(f"price distribution {i}")
#
# TypeError: 'int' object is not iterable
